# %% [markdown]
# # **10.1.1 実行中のプロセス属性の操作**

# %%
# 環境変数にアクセスする
import os

os.environ['HOME']
os.environ['HAM'] = 'egg'

# %% [markdown]
# # **10.1.2 ファイルとディレクトリの操作**

# %%
# 基本的なファイル操作
print(os.getcwd())
os.chdir('/tmp')
os.mkdir('test')
print(os.listdir('.'))
os.rmdir('test')
# Out:
# /tmp
# ['dap_multiplexer.INFO', 'pyright-197-tdXJ28I8rIIg', 'language_service.INFO', 'dap_multiplexer.cd7e086f7337.root.log.INFO.20240716-014912.81', 'pyright-3512-1jCn3o9q6VYG', 'tmpmup1mn8k', 'language_service.cd7e086f7337.root.log.INFO.20240716-014926.189', 'debugger_1rlyo82d5y', 'pyright-3512-z003toNbH1Y7', 'initgoogle_syslog_dir.0', 'python-languageserver-cancellation', 'test', 'language_service.cd7e086f7337.root.log.INFO.20240716-020313.3507']
