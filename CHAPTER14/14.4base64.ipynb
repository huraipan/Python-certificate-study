# %% [markdown]
# # **14.4.1 Base64にエンコードする**

# %%
# Base64のエンコード
import base64

s = 'Python は簡単に習得でき、それでいて強力な言語の１つです。'
# base64.b64encode(s)       typeError
print(base64.b64encode(s.encode()))
print(base64.b64encode(s.encode(), altchars=b'@*'))
# Out:
# b'UHl0aG9uIOOBr+ewoeWNmOOBq+e/kuW+l+OBp+OBjeOAgeOBneOCjOOBp+OBhOOBpuW8t+WKm+OBquiogOiqnuOBru+8keOBpOOBp+OBmeOAgg=='
# b'UHl0aG9uIOOBr@ewoeWNmOOBq@e*kuW@l@OBp@OBjeOAgeOBneOCjOOBp@OBhOOBpuW8t@WKm@OBquiogOiqnuOBru@8keOBpOOBp@OBmeOAgg=='

# %% [markdown]
# # **14.4.2 Base64からデコードする**

# %%
# Base64のデコード
s = 'Python は簡単に習得でき、それでいて強力な言語の１つです。'
enc_s = base64.b64encode(s.encode())
print(base64.b64decode(enc_s).decode())

enc_s = base64.b64encode(s.encode(), altchars=b'-_')
# base64.b64decode(enc_s, validate=True)        binascii.Error
