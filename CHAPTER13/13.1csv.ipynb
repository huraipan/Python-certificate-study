# %% [markdown]
# # **13.1.1 CSVファイルの読み込みと書き込み**

# %%
# CSVファイルの読み込み
import csv

with open('sample.csv', mode='r', encoding='utf-8') as f:
    reader = csv.reader(f)
    for row in reader:
        print(now)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-320f80a14776> in <cell line: 4>()
#       2 import csv
#       3
# ----> 4 with open('sample.csv', mode='r', encoding='utf-8') as f:
#       5     reader = csv.reader(f)
#       6     for row in reader:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample.csv'

# %%
# デリミター、引用符の指定
with open('sample.tsv', mode='r') as f:
    reader = csv.reader(f, delimiter='\t')
    for row in reader:
        print(row)

with open('sample.tsv', mode='r') as f:
    reader = csv.reader(f, delimiter='\t', quotechar='#')
    for row in reader:
        print(row)

# %% [markdown]
# # **13.1.2 辞書データを用いたCSVファイルの読み込みと書き込み**

# %%
# DictReader()を利用した読み込み
with open('sample.csv', mode='r', encoding='utf-8') as f:
    for row in csv.DictReader(F):
        print(row)

# %% [markdown]
# # **13.1.4 csv:ちょっと役立周辺知識**

# %%
# Snifferクラスを使用し自動判別
with open('result.csv', newline='') as f:
    dialect = csv.Sniffer().sniff(f.read(1024))
    f.seek(0)
    reader = csv.reader(f, dialect)
    for row in reader:
        print(row)
