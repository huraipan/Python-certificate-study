# %% [markdown]
# # **8.3.1 IANAタイムゾーンを表すオブジェクトーZoneInfo**

# %%
# zoneinfo.ZoneInfo
from zoneinfo import ZoneInfo
from datetime import datetime

ASIA_TOKYO = ZoneInfo('Asia/Tokyo')
print(ASIA_TOKYO)

dt = datetime(2021, 2, 23, 10, tzinfo=ASIA_TOKYO)
print(dt)
print(dt.astimezone(ZoneInfo('America/Los_Angeles')))
# Out:
# Asia/Tokyo
# 2021-02-23 10:00:00+09:00
# 2021-02-22 17:00:00-08:00

# %%
# zoneinfo.ZoneInfoとdatetimeのfold属性を組み合わせた例
dt = datetime(2020, 11, 1, 1, tzinfo=ZoneInfo('America/Los_Angeles'))
print(dt)
print(dt.replace(fold=1))
# Out:
# 2020-11-01 01:00:00-07:00
# 2020-11-01 01:00:00-08:00

# %%
# Out:
# 2.511111111111111
